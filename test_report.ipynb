# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
big_data = pd.read_excel("p1_data.xlsx", sheetname=0)

# %%
big_data = big_data.fillna(value="missing")      # Fill NaN/missing/default value
big_data.columns
# Out:
# Index(['Name ', 'Date', 'Shift', 'Company*+', 'Incident ID*+', 'Assigned Group'], dtype='object')

# %%
big_data.T
# Out:
#                               0                    1                    2      \
# Name                    Rishi Wagal          Rishi Wagal          Rishi Wagal
# Date            2014-07-09 00:00:00  2014-07-09 00:00:00  2014-07-09 00:00:00
# Shift                       Shift A              Shift A              Shift A
# Company*+                   missing              missing              missing
# Incident ID*+       INC000000600307      INC000000600308     INC000000600513
# Assigned Group              missing              missing              missing
#
#                               3                    4                    5      \
# Name                  Manthan Desai        Manthan Desai        Manthan Desai
# Date            2014-07-09 00:00:00  2014-07-09 00:00:00  2014-07-09 00:00:00
# Shift                       Shift A              Shift A              Shift A
# Company*+                   missing              missing              missing
# Incident ID*+       INC000000600305      INC000000600363      INC000000600361
# Assigned Group              missing              missing              missing
#
#                               6                    7                    8      \
# Name                  Manthan Desai        Manthan Desai        Manthan Desai
# Date            2014-07-09 00:00:00  2014-07-09 00:00:00  2014-07-09 00:00:00
# Shift                       Shift A              Shift A              Shift A
# Company*+                   missing              missing              missing
# Incident ID*+      INC000000600384       INC000011308988      INC000000600386
# Assigned Group              missing              missing              missing
#
#                               9                     ...                   \
# Name                  Manthan Desai                 ...
# Date            2014-07-09 00:00:00                 ...
# Shift                       Shift A                 ...
# Company*+                   missing                 ...
# Incident ID*+       INC000000600534                 ...
# Assigned Group              missing                 ...
#
#                                               18261  \
# Name                                  Manthan Desai
# Date                            2015-03-19 00:00:00
# Shift                                       Shift B
# Company*+             SOK IT Päivittäistavarakauppa
# Incident ID*+                       INC000001348125
# Assigned Group  S-ryhmä FI.CADM TOPSI Replenishment
#
#                                               18262  \
# Name                                  Manthan Desai
# Date                            2015-03-19 00:00:00
# Shift                                       Shift B
# Company*+             SOK IT Päivittäistavarakauppa
# Incident ID*+                       INC000001348126
# Assigned Group  S-ryhmä FI.CADM TOPSI Replenishment
#
#                                               18263  \
# Name                                  Manthan Desai
# Date                            2015-03-19 00:00:00
# Shift                                       Shift B
# Company*+             SOK IT Päivittäistavarakauppa
# Incident ID*+                       INC000001348127
# Assigned Group  S-ryhmä FI.CADM TOPSI Replenishment
#
#                                               18264  \
# Name                                  Manthan Desai
# Date                            2015-03-19 00:00:00
# Shift                                       Shift B
# Company*+             SOK IT Päivittäistavarakauppa
# Incident ID*+                       INC000001348128
# Assigned Group  S-ryhmä FI.CADM TOPSI Replenishment
#
#                                         18265                        18266  \
# Name                            Manthan Desai                Manthan Desai
# Date                      2015-03-19 00:00:00          2015-03-19 00:00:00
# Shift                                 Shift B                      Shift B
# Company*+       SOK IT Päivittäistavarakauppa                Ruokakesko Oy
# Incident ID*+                 INC000001347999              INC000001349096
# Assigned Group        CG FI.CADM Service Desk  CG MUM.SAP ADM Service Desk
#
#                               18267                                18268  \
# Name                  Manthan Desai                       Himanshu Dubey
# Date            2015-03-19 00:00:00                  2015-03-19 00:00:00
# Shift                       Shift B                              Shift B
# Company*+                  Hartwall        SOK IT Päivittäistavarakauppa
# Incident ID*+       INC000001349904                      INC000001348145
# Assigned Group   CG IMOC-L2 NO Unix  S-ryhmä FI.CADM TOPSI Replenishment
#
#                                               18269  \
# Name                                 Himanshu Dubey
# Date                            2015-03-19 00:00:00
# Shift                                       Shift B
# Company*+             SOK IT Päivittäistavarakauppa
# Incident ID*+                       INC000001348139
# Assigned Group  S-ryhmä FI.CADM TOPSI Replenishment
#
#                                               18270
# Name                                 Himanshu Dubey
# Date                            2015-03-19 00:00:00
# Shift                                       Shift B
# Company*+             SOK IT Päivittäistavarakauppa
# Incident ID*+                       INC000001348140
# Assigned Group  S-ryhmä FI.CADM TOPSI Replenishment
#
# [6 rows x 18271 columns]

# %%
big_data.describe()
# Out:
#                 Name                  Date    Shift      Company*+  \
# count           18271                18271    18271          18271
# unique             19                  255        5             95
# top     Manthan Desai  2014-11-21 00:00:00  Shift B  Ruokakesko Oy
# freq             3204                  365     6693           4189
#
#        Incident ID*+               Assigned Group
# count          18271                        18271
# unique         17971                          114
# top          missing  CG MUM.SAP ADM Service Desk
# freq              18                         5524

# %%
big_data.groupby("Name ").count().plot(kind='bar')

# %%
big_data.groupby("Name ").get_group('Praveen Thapliyal').groupby("Name ").count()
big_data.groupby("Name ").count()
# Out:
#                     Date  Shift  Company*+  Incident ID*+  Assigned Group
# Name
#  Praveen Thapliyal     3      3          3              3               3
# HIMANSHU DUBEY        39     39         39             39              39
# Hari Mittapalli     2469   2469       2469           2469            2469
# Himanshu Dubey       256    256        256            256             256
# Krupali Tikam        552    552        552            552             552
# Manthan Desai       3204   3204       3204           3204            3204
# Mathew Renol           2      2          2              2               2
# Monish Patil        1008   1008       1008           1008            1008
# Nikhil Nikam         997    997        997            997             997
# Ponbala lp          2998   2998       2998           2998            2998
# Praveen Thapliyal   2961   2961       2961           2961            2961
# Renol Mathew          20     20         20             20              20
# Rishi Wagal           11     11         11             11              11
# Shivu Kumar         2322   2322       2322           2322            2322
# Shoeb Kazi           942    942        942            942             942
# Sujata Bramhraj       10     10         10             10              10
# Sujata Gaikwad       448    448        448            448             448
# krupali Tikam          4      4          4              4               4
# shoeb Kazi            25     25         25             25              25

# %%
big_data_Praveen_Thapliyal = (big_data.groupby("Name ")).get_group('Praveen Thapliyal')

# %%
big_data_Praveen_Thapliyal.groupby('Incident ID*+').get_group('missing')
# Out:
#                    Name                  Date    Shift Company*+  \
# 13952  Praveen Thapliyal  2015-01-11 00:00:00  Shift C   missing
# 13953  Praveen Thapliyal  2015-01-11 00:00:00  Shift C   missing
# 13954  Praveen Thapliyal  2015-01-11 00:00:00  Shift C   missing
# 13955  Praveen Thapliyal  2015-01-11 00:00:00  Shift C   missing
# 13956  Praveen Thapliyal  2015-01-11 00:00:00  Shift C   missing
# 13957  Praveen Thapliyal  2015-01-11 00:00:00  Shift C   missing
# 13958  Praveen Thapliyal  2015-01-11 00:00:00  Shift C   missing
#
#       Incident ID*+ Assigned Group
# 13952       missing        missing
# 13953       missing        missing
# 13954       missing        missing
# 13955       missing        missing
# 13956       missing        missing
# 13957       missing        missing
# 13958       missing        missing
